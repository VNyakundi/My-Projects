# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

pd.json_normalize(data['data'])
# Out:
#          id         name  symbol       slug  num_market_pairs  \
# 0         1      Bitcoin     BTC    bitcoin             11945
# 1      1027     Ethereum     ETH   ethereum              9932
# 2        52          XRP     XRP        xrp              1534
# 3       825  Tether USDt    USDT     tether            116937
# 4      1839          BNB     BNB        bnb              2362
# ...     ...          ...     ...        ...               ...
# 4995  35149        nomAI   NOMAI      nomai                 6
# 4996  17601        ONINO     ONI  oni-token                28
# 4997  16747       Savage    SAVG     savage                 6
# 4998   5625  LUKSO [Old]    LYXe      lukso                43
# 4999  34655       Gemini  GEMINI   gemini-2                 3
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2013-08-04T00:00:00.000Z
# 3     2015-02-25T00:00:00.000Z
# 4     2017-07-25T00:00:00.000Z
# ...                        ...
# 4995  2025-01-10T03:14:38.000Z
# 4996  2022-01-24T12:43:12.000Z
# 4997  2022-01-03T04:16:10.000Z
# 4998  2020-05-25T00:00:00.000Z
# 4999  2024-12-16T11:32:28.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 3     [stablecoin, asset-backed-stablecoin, ethereum...           NaN
# 4     [marketplace, centralized-exchange, payments, ...           NaN
# ...                                                 ...           ...
# 4995  [base-ecosystem, ai-agents, virtuals-protocol-...  9.998617e+08
# 4996  [ethereum-ecosystem, bnb-chain-ecosystem, real...           NaN
# 4997                   [marketplace, collectibles-nfts]           NaN
# 4998  [collectibles-nfts, ethereum-ecosystem, metave...  1.000000e+08
# 4999           [memes, solana-ecosystem, zodiac-themed]  1.000000e+09
#
#       circulating_supply         total_supply  infinite_supply  platform  \
# 0           1.982556e+07             19825559            False       NaN
# 1           1.205553e+08     120555264.231012             True       NaN
# 2           5.781886e+10          99986451428            False       NaN
# 3           1.419965e+11  143566824829.421204             True       NaN
# 4           1.424774e+08         142477401.73            False       NaN
# ...                  ...                  ...              ...       ...
# 4995        0.000000e+00            999861673            False       NaN
# 4996        0.000000e+00      39153628.753484            False       NaN
# 4997        0.000000e+00           1000000000            False       NaN
# 4998        0.000000e+00      99999999.638752            False       NaN
# 4999        0.000000e+00            999884643            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4996                      9.998617e+08              2.883061e+06
# 4996      4997                      3.915363e+07              3.357877e+06
# 4997      4998                      5.516917e+07              1.947460e+04
# 4998      4999                      1.860000e+07              2.644072e+07
# 4999      5000                      9.998846e+08              9.062025e+05
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2025-02-17T14:03:00.000Z     96455.994607
# 1           NaN  2025-02-17T14:03:00.000Z      2782.998773
# 2           NaN  2025-02-17T14:04:00.000Z         2.685957
# 3           NaN  2025-02-17T14:04:00.000Z         1.000168
# 4           NaN  2025-02-17T14:04:00.000Z       676.847161
# ...         ...                       ...              ...
# 4995        NaN  2025-02-17T14:04:00.000Z         0.002883
# 4996        NaN  2025-02-17T14:04:00.000Z         0.085762
# 4997        NaN  2025-02-17T14:04:00.000Z         0.000353
# 4998        NaN  2025-02-17T14:04:00.000Z         1.421544
# 4999        NaN  2025-02-17T14:04:00.000Z         0.000906
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             2.139519e+10                      60.2667
# 1             1.565498e+10                      69.7801
# 2             4.228983e+09                      18.0437
# 3             5.911882e+10                      32.1529
# 4             2.086895e+09                      17.6644
# ...                    ...                          ...
# 4995          1.496885e+04                     -42.0890
# 4996          1.495527e+04                      -2.8692
# 4997          1.490643e+04                    1184.5162
# 4998          1.488098e+04                     120.2290
# 4999          1.487141e+04                      59.8441
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                        0.021979                     -0.268249
# 1                        0.636787                      3.736239
# 2                       -0.039518                     -1.480257
# 3                        0.011686                      0.012103
# 4                        0.308817                      1.990821
# ...                           ...                           ...
# 4995                    -1.479006                    -11.064838
# 4996                    -0.190082                      5.301154
# 4997                     0.006262                      8.269792
# 4998                     0.000000                     -1.675867
# 4999                     0.000000                     -8.475009
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       -1.669067                     -7.495945
# 1                        4.118756                    -16.055587
# 2                        9.423963                    -16.793237
# 3                        0.001325                      0.061765
# 4                       11.443802                     -4.110708
# ...                           ...                           ...
# 4995                   -37.341208                    -84.776141
# 4996                    -0.415671                    -10.618969
# 4997                   -10.431390                    -49.624924
# 4998                    -0.517928                    -34.069552
# 4999                   -27.194126                    -83.224004
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                        -5.516003                      5.636915
# 1                       -24.500214                    -10.000648
# 2                        13.210319                    148.463650
# 3                         0.062152                     -0.036353
# 4                        -3.368394                     10.198228
# ...                            ...                           ...
# 4995                    -85.778248                    389.524589
# 4996                    -18.299541                     41.048603
# 4997                    -53.468157                    -60.446146
# 4998                    -48.007566                     -2.348923
# 4999                    -91.326699                    -92.367575
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             1.912294e+12                         59.5050
# 1             3.355052e+11                         10.4410
# 2             1.552990e+11                          4.8329
# 3             1.420203e+11                          4.4193
# 4             9.643542e+10                          3.0008
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           2.025576e+12            NaN
# 1                           3.355052e+11            NaN
# 2                           2.685957e+11            NaN
# 3                           1.435909e+11            NaN
# 4                           9.643542e+10            NaN
# ...                                  ...            ...
# 4995                        2.883061e+06            NaN
# 4996                        3.357877e+06            NaN
# 4997                        3.529978e+05            NaN
# 4998                        1.421544e+08            NaN
# 4999                        9.063071e+05            NaN
#
#         quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0     2025-02-17T14:03:00.000Z          NaN           NaN             NaN
# 1     2025-02-17T14:03:00.000Z          NaN           NaN             NaN
# 2     2025-02-17T14:04:00.000Z          NaN           NaN             NaN
# 3     2025-02-17T14:04:00.000Z       1027.0      Ethereum             ETH
# 4     2025-02-17T14:04:00.000Z          NaN           NaN             NaN
# ...                        ...          ...           ...             ...
# 4995  2025-02-17T14:04:00.000Z          NaN           NaN             NaN
# 4996  2025-02-17T14:04:00.000Z       1027.0      Ethereum             ETH
# 4997  2025-02-17T14:04:00.000Z          NaN           NaN             NaN
# 4998  2025-02-17T14:04:00.000Z       1027.0      Ethereum             ETH
# 4999  2025-02-17T14:04:00.000Z       5426.0        Solana             SOL
#
#      platform.slug                        platform.token_address
# 0              NaN                                           NaN
# 1              NaN                                           NaN
# 2              NaN                                           NaN
# 3         ethereum    0xdac17f958d2ee523a2206206994597c13d831ec7
# 4              NaN                                           NaN
# ...            ...                                           ...
# 4995           NaN                                           NaN
# 4996      ethereum    0x822757d09a8d5db5874be7f367eafae2af32d64b
# 4997           NaN                                           NaN
# 4998      ethereum    0xA8b919680258d369114910511cc87595aec0be6D
# 4999        solana  ARiZfq6dK19uNqxWyRudhbM2MswLyYhVUHdndGkffdGc
#
# [5000 rows x 36 columns]
